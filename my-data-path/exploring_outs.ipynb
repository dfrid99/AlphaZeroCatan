# %%
import json

with open('./00d8d317-dd4b-44a2-b535-c3b0cbeba343.json') as file:
    data = json.load(file)

data.keys()
# Out:
# dict_keys(['tiles', 'adjacent_tiles', 'nodes', 'edges', 'actions', 'player_state', 'colors', 'bot_colors', 'is_initial_build_phase', 'robber_coordinate', 'current_color', 'current_prompt', 'current_playable_actions', 'longest_roads_by_player', 'winning_color'])

# %%
data['actions']
# Out:
# [['BLUE', 'BUILD_SETTLEMENT', 2],
#  ['BLUE', 'BUILD_ROAD', [2, 3]],
#  ['RED', 'BUILD_SETTLEMENT', 45],
#  ['RED', 'BUILD_ROAD', [45, 46]],
#  ['RED', 'BUILD_SETTLEMENT', 30],
#  ['RED', 'BUILD_ROAD', [29, 30]],
#  ['BLUE', 'BUILD_SETTLEMENT', 24],
#  ['BLUE', 'BUILD_ROAD', [24, 53]],
#  ['BLUE', 'ROLL', [4, 1]],
#  ['BLUE', 'BUILD_ROAD', [24, 25]],
#  ['BLUE', 'END_TURN', None],
#  ['RED', 'ROLL', [2, 2]],
#  ['RED', 'END_TURN', None],
#  ['BLUE', 'ROLL', [4, 1]],
#  ['BLUE', 'END_TURN', None],
#  ['RED', 'ROLL', [3, 6]],
#  ['RED', 'END_TURN', None],
#  ['BLUE', 'ROLL', [4, 4]],
#  ['BLUE', 'END_TURN', None],
#  ['RED', 'ROLL', [5, 3]],
#  ['RED', 'END_TURN', None],
#  ['BLUE', 'ROLL', [5, 6]],
#  ['BLUE', 'END_TURN', None],
#  ['RED', 'ROLL', [6, 6]],
#  ['RED', 'END_TURN', None],
#  ['BLUE', 'ROLL', [4, 3]],
#  ['BLUE', 'MOVE_ROBBER', [[1, -2, 1], None, None]],
#  ['BLUE', 'BUILD_ROAD', [52, 53]],
#  ['BLUE', 'END_TURN', None],
#  ['RED', 'ROLL', [3, 1]],
# ...
